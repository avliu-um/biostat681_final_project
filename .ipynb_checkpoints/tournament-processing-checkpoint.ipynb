# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm

# %%
games = pd.read_csv('data/games.csv').iloc[:,1:]
players = pd.read_csv('data/players.csv').iloc[1:,:]
tournaments = pd.read_csv('data/tournaments.csv')

# %%
games.head()
# Out:
#    upset_score  tournament_id  left_fide_id  left_rtg  right_fide_id  \
# 0          0.0       686540.0    13724800.0      1630      4404637.0
# 1          0.0       686540.0    45076995.0      1156     16233751.0
# 2          0.0       686540.0    25683896.0      1537      5602637.0
# 3        698.0       686540.0    41822412.0         0       472000.0
# 4          0.0       686540.0     9307010.0      1362      9325190.0
#
#    right_rtg         location   medium      time_control
# 0     1306.0  Mellieha, Malta  offline  90min+30sec/move
# 1     1615.0  Mellieha, Malta  offline  90min+30sec/move
# 2     1145.0  Mellieha, Malta  offline  90min+30sec/move
# 3     1396.0  Mellieha, Malta  offline  90min+30sec/move
# 4        0.0  Mellieha, Malta  offline  90min+30sec/move

# %%
games.shape
# Out:
# (66162, 9)

# %%
players.head()
# Out:
#                     Name    FideID
# 1  Margadgua Erdenebayar   4904052
# 2        Alipbek Arailym  13724800
# 3       Von Beckh Frieda  16233751
# 4      Amulya Guruprasad  25683896
# 5       Cuthbert Larissa    472000

# %%
tournaments.head()
# Out:
#    tournament_id                                             url  \
# 0         686540  https://chess-results.com/tnr686540.aspx?lan=1
# 1         669871  https://chess-results.com/tnr669871.aspx?lan=1
# 2         686538  https://chess-results.com/tnr686538.aspx?lan=1
# 3         686539  https://chess-results.com/tnr686539.aspx?lan=1
# 4         670407  https://chess-results.com/tnr670407.aspx?lan=1
#
#                      location   medium                     time_control
# 0             Mellieha, Malta  offline                 90min+30sec/move
# 1             Mellieha, Malta  offline                 90min+30sec/move
# 2             Mellieha, Malta  offline                 90min+30sec/move
# 3             Mellieha, Malta  offline                 90min+30sec/move
# 4  Cala Gonone - Dorgali (NU)  offline  90'/40 moves + 30' + 30'' bonus

# %%
tournaments.shape
# Out:
# (313, 5)

# %% [markdown]
# ### Step 1: filter tournament in which both left_rtg and right_rtg are greater than zero

# %%
games = games.loc[(games['left_rtg'] > 0) & (games['right_rtg'] > 0)]

# %%
games.shape
# Out:
# (57963, 9)

# %% [markdown]
# ### Step 2: removing duplicates

# %%
games.groupby(['left_fide_id', 'right_fide_id']).size().reset_index().sort_values(0, ascending = False)
# Out:
#        left_fide_id  right_fide_id   0
# 8805      4168119.0      4126025.0  59
# 8564      4126025.0      4135539.0  58
# 21987    24116068.0       623539.0  58
# 3517      1271102.0     12903892.0  58
# 3515      1271102.0      4653130.0  58
# ...             ...            ...  ..
# 9079      4250990.0      1227556.0   1
# 9078      4250990.0       224715.0   1
# 9077      4248961.0     35018361.0   1
# 9076      4247019.0     14116367.0   1
# 26960   651083248.0     33329664.0   1
#
# [26961 rows x 3 columns]

# %%
games.loc[(games['left_fide_id'] == 4168119) & (games['right_fide_id'] == 4126025)]
# Out:
#        upset_score  tournament_id  left_fide_id  left_rtg  right_fide_id  \
# 22808          0.0       600854.0     4168119.0      2792      4126025.0
# 24773          0.0       600852.0     4168119.0      2798      4126025.0
# 52899          6.0       557461.0     4168119.0      2789      4126025.0
# 52954          6.0       557461.0     4168119.0      2789      4126025.0
# 53009          6.0       557461.0     4168119.0      2789      4126025.0
# 53064          6.0       557461.0     4168119.0      2789      4126025.0
# 53119          6.0       557461.0     4168119.0      2789      4126025.0
# 53174          6.0       557461.0     4168119.0      2789      4126025.0
# 53229          6.0       557461.0     4168119.0      2789      4126025.0
# 53284          6.0       557461.0     4168119.0      2789      4126025.0
# 53339          6.0       557461.0     4168119.0      2789      4126025.0
# 53394          6.0       557461.0     4168119.0      2789      4126025.0
# 53449          6.0       557461.0     4168119.0      2789      4126025.0
# 53504          6.0       557461.0     4168119.0      2789      4126025.0
# 53559          6.0       557461.0     4168119.0      2789      4126025.0
# 53614          6.0       557461.0     4168119.0      2789      4126025.0
# 53669          6.0       557461.0     4168119.0      2789      4126025.0
# 53724          6.0       557461.0     4168119.0      2789      4126025.0
# 53779          6.0       557461.0     4168119.0      2789      4126025.0
# 53834          6.0       557461.0     4168119.0      2789      4126025.0
# 53889          6.0       557461.0     4168119.0      2789      4126025.0
# 53944          6.0       557637.0     4168119.0      2789      4126025.0
# 53999          6.0       557637.0     4168119.0      2789      4126025.0
# 54054          6.0       557637.0     4168119.0      2789      4126025.0
# 54109          6.0       557637.0     4168119.0      2789      4126025.0
# 54164          6.0       557637.0     4168119.0      2789      4126025.0
# 54219          6.0       557637.0     4168119.0      2789      4126025.0
# 54274          6.0       557637.0     4168119.0      2789      4126025.0
# 54329          6.0       557637.0     4168119.0      2789      4126025.0
# 54384          6.0       557637.0     4168119.0      2789      4126025.0
# 54439          6.0       557637.0     4168119.0      2789      4126025.0
# 54494          6.0       557637.0     4168119.0      2789      4126025.0
# 54549          6.0       557637.0     4168119.0      2789      4126025.0
# 54604          6.0       557637.0     4168119.0      2789      4126025.0
# 54659          6.0       557637.0     4168119.0      2789      4126025.0
# 54714          6.0       557637.0     4168119.0      2789      4126025.0
# 54769          6.0       557637.0     4168119.0      2789      4126025.0
# 54824          6.0       557637.0     4168119.0      2789      4126025.0
# 54879          6.0       557637.0     4168119.0      2789      4126025.0
# 54934          6.0       557637.0     4168119.0      2789      4126025.0
# 65121          1.5       525314.0     4168119.0      2774      4126025.0
# 65176          1.5       525314.0     4168119.0      2774      4126025.0
# 65231          1.5       525314.0     4168119.0      2774      4126025.0
# 65286          1.5       525314.0     4168119.0      2774      4126025.0
# 65341          1.5       525314.0     4168119.0      2774      4126025.0
# 65396          1.5       525314.0     4168119.0      2774      4126025.0
# 65451          1.5       525314.0     4168119.0      2774      4126025.0
# 65506          1.5       525314.0     4168119.0      2774      4126025.0
# 65561          1.5       525314.0     4168119.0      2774      4126025.0
# 65616          1.5       525314.0     4168119.0      2774      4126025.0
# 65671          1.5       525314.0     4168119.0      2774      4126025.0
# 65726          1.5       525314.0     4168119.0      2774      4126025.0
# 65781          1.5       525314.0     4168119.0      2774      4126025.0
# 65836          1.5       525314.0     4168119.0      2774      4126025.0
# 65891          1.5       525314.0     4168119.0      2774      4126025.0
# 65946          1.5       525314.0     4168119.0      2774      4126025.0
# 66001          1.5       525314.0     4168119.0      2774      4126025.0
# 66056          1.5       525314.0     4168119.0      2774      4126025.0
# 66111          1.5       525314.0     4168119.0      2774      4126025.0
#
#        right_rtg                      location   medium  \
# 22808     2757.0  PGE Narodowy, Warsaw, Poland  offline
# 24773     2763.0  PGE Narodowy, Warsaw, Poland  offline
# 52899     2777.0                 Yekaterinburg  offline
# 52954     2777.0                 Yekaterinburg  offline
# 53009     2777.0                 Yekaterinburg  offline
# 53064     2777.0                 Yekaterinburg  offline
# 53119     2777.0                 Yekaterinburg  offline
# 53174     2777.0                 Yekaterinburg  offline
# 53229     2777.0                 Yekaterinburg  offline
# 53284     2777.0                 Yekaterinburg  offline
# 53339     2777.0                 Yekaterinburg  offline
# 53394     2777.0                 Yekaterinburg  offline
# 53449     2777.0                 Yekaterinburg  offline
# 53504     2777.0                 Yekaterinburg  offline
# 53559     2777.0                 Yekaterinburg  offline
# 53614     2777.0                 Yekaterinburg  offline
# 53669     2777.0                 Yekaterinburg  offline
# 53724     2777.0                 Yekaterinburg  offline
# 53779     2777.0                 Yekaterinburg  offline
# 53834     2777.0                 Yekaterinburg  offline
# 53889     2777.0                 Yekaterinburg  offline
# 53944     2777.0                 Yekaterinburg  offline
# 53999     2777.0                 Yekaterinburg  offline
# 54054     2777.0                 Yekaterinburg  offline
# 54109     2777.0                 Yekaterinburg  offline
# 54164     2777.0                 Yekaterinburg  offline
# 54219     2777.0                 Yekaterinburg  offline
# 54274     2777.0                 Yekaterinburg  offline
# 54329     2777.0                 Yekaterinburg  offline
# 54384     2777.0                 Yekaterinburg  offline
# 54439     2777.0                 Yekaterinburg  offline
# 54494     2777.0                 Yekaterinburg  offline
# 54549     2777.0                 Yekaterinburg  offline
# 54604     2777.0                 Yekaterinburg  offline
# 54659     2777.0                 Yekaterinburg  offline
# 54714     2777.0                 Yekaterinburg  offline
# 54769     2777.0                 Yekaterinburg  offline
# 54824     2777.0                 Yekaterinburg  offline
# 54879     2777.0                 Yekaterinburg  offline
# 54934     2777.0                 Yekaterinburg  offline
# 65121     2777.0                 Yekaterinburg  offline
# 65176     2777.0                 Yekaterinburg  offline
# 65231     2777.0                 Yekaterinburg  offline
# 65286     2777.0                 Yekaterinburg  offline
# 65341     2777.0                 Yekaterinburg  offline
# 65396     2777.0                 Yekaterinburg  offline
# 65451     2777.0                 Yekaterinburg  offline
# 65506     2777.0                 Yekaterinburg  offline
# 65561     2777.0                 Yekaterinburg  offline
# 65616     2777.0                 Yekaterinburg  offline
# 65671     2777.0                 Yekaterinburg  offline
# 65726     2777.0                 Yekaterinburg  offline
# 65781     2777.0                 Yekaterinburg  offline
# 65836     2777.0                 Yekaterinburg  offline
# 65891     2777.0                 Yekaterinburg  offline
# 65946     2777.0                 Yekaterinburg  offline
# 66001     2777.0                 Yekaterinburg  offline
# 66056     2777.0                 Yekaterinburg  offline
# 66111     2777.0                 Yekaterinburg  offline
#
#                             time_control
# 22808                     3min+2sec/move
# 24773                   15min+10sec/move
# 52899  100'/40+50'/20+15'+30'' Increment
# 52954  100'/40+50'/20+15'+30'' Increment
# 53009  100'/40+50'/20+15'+30'' Increment
# 53064  100'/40+50'/20+15'+30'' Increment
# 53119  100'/40+50'/20+15'+30'' Increment
# 53174  100'/40+50'/20+15'+30'' Increment
# 53229  100'/40+50'/20+15'+30'' Increment
# 53284  100'/40+50'/20+15'+30'' Increment
# 53339  100'/40+50'/20+15'+30'' Increment
# 53394  100'/40+50'/20+15'+30'' Increment
# 53449  100'/40+50'/20+15'+30'' Increment
# 53504  100'/40+50'/20+15'+30'' Increment
# 53559  100'/40+50'/20+15'+30'' Increment
# 53614  100'/40+50'/20+15'+30'' Increment
# 53669  100'/40+50'/20+15'+30'' Increment
# 53724  100'/40+50'/20+15'+30'' Increment
# 53779  100'/40+50'/20+15'+30'' Increment
# 53834  100'/40+50'/20+15'+30'' Increment
# 53889  100'/40+50'/20+15'+30'' Increment
# 53944  100'/40+50'/20+15'+30'' Increment
# 53999  100'/40+50'/20+15'+30'' Increment
# 54054  100'/40+50'/20+15'+30'' Increment
# 54109  100'/40+50'/20+15'+30'' Increment
# 54164  100'/40+50'/20+15'+30'' Increment
# 54219  100'/40+50'/20+15'+30'' Increment
# 54274  100'/40+50'/20+15'+30'' Increment
# 54329  100'/40+50'/20+15'+30'' Increment
# 54384  100'/40+50'/20+15'+30'' Increment
# 54439  100'/40+50'/20+15'+30'' Increment
# 54494  100'/40+50'/20+15'+30'' Increment
# 54549  100'/40+50'/20+15'+30'' Increment
# 54604  100'/40+50'/20+15'+30'' Increment
# 54659  100'/40+50'/20+15'+30'' Increment
# 54714  100'/40+50'/20+15'+30'' Increment
# 54769  100'/40+50'/20+15'+30'' Increment
# 54824  100'/40+50'/20+15'+30'' Increment
# 54879  100'/40+50'/20+15'+30'' Increment
# 54934  100'/40+50'/20+15'+30'' Increment
# 65121  100'/40+50'/20+15'+30'' Increment
# 65176  100'/40+50'/20+15'+30'' Increment
# 65231  100'/40+50'/20+15'+30'' Increment
# 65286  100'/40+50'/20+15'+30'' Increment
# 65341  100'/40+50'/20+15'+30'' Increment
# 65396  100'/40+50'/20+15'+30'' Increment
# 65451  100'/40+50'/20+15'+30'' Increment
# 65506  100'/40+50'/20+15'+30'' Increment
# 65561  100'/40+50'/20+15'+30'' Increment
# 65616  100'/40+50'/20+15'+30'' Increment
# 65671  100'/40+50'/20+15'+30'' Increment
# 65726  100'/40+50'/20+15'+30'' Increment
# 65781  100'/40+50'/20+15'+30'' Increment
# 65836  100'/40+50'/20+15'+30'' Increment
# 65891  100'/40+50'/20+15'+30'' Increment
# 65946  100'/40+50'/20+15'+30'' Increment
# 66001  100'/40+50'/20+15'+30'' Increment
# 66056  100'/40+50'/20+15'+30'' Increment
# 66111  100'/40+50'/20+15'+30'' Increment

# %%
tournaments.loc[tournaments['tournament_id'] == 557461]
# Out:
#      tournament_id                                             url  \
# 240         557461  https://chess-results.com/tnr557461.aspx?lan=1
#
#           location   medium                       time_control
# 240  Yekaterinburg  offline  100'/40+50'/20+15'+30'' Increment

# %% [markdown]
# ### In Yekaterinburg, these two players only met twice.. for simplicity, let's remove all duplicates

# %%
games = games.drop_duplicates()

# %%
games.shape
# Out:
# (27629, 9)

# %% [markdown]
# ### Step 3: get the start date of each tournament to get covariates

# %%
all_tournaments = games[['tournament_id']].drop_duplicates().reset_index(drop = True)

# %%
url = "./chess_results.html"
with open(url) as fp:
    soup = BeautifulSoup(fp, 'html.parser')

# %%
tour_ids = []
start_dates = []

temps = soup.findAll("a", href = True)

for temp in temps:
    if '/tnr' in temp['href']:
        tour_ids.append(int(temp['href'].split('/')[-1].split('.')[0][3:]))
        start_dates.append(temp.findNext('td').text)

# %%
tour_dates_df = pd.DataFrame(columns = ['id', 'start_date'])
tour_dates_df['id'] = tour_ids
tour_dates_df['start_date'] = start_dates

# %%
tour_dates_df
# Out:
#          id  start_date
# 0    686540  2022/10/21
# 1    669871  2022/10/21
# 2    686538  2022/10/21
# 3    686539  2022/10/21
# 4    670407  2022/10/12
# ..      ...         ...
# 367  527178  2020/05/08
# 368  525314  2020/03/17
# 369  491115  2020/03/06
# 370  491114  2020/03/06
# 371  503449  2020/01/03
#
# [372 rows x 2 columns]

# %%
games = games.merge(tour_dates_df, how = 'left', left_on = 'tournament_id', right_on = 'id')
games = games.drop(columns = ['id'])

# %% [markdown]
# ### Step 4: map location to country; fix lichess -> online

# %%
locs = list(games['location'].unique())
countries = ['Malta', 'Italy', 'Spain', 'Georgia', 'Belgium', 'Romania', 'Poland',
             'United States of America', 'Hungary', 'India', 'India', 'Panama',
            'Italy', 'Russia', 'Israel', 'Greece', 'Greece', 'Greece', 'Greece',
            'Kazakhstan', 'Bangladesh', 'Kenya', 'Kenya', 'Poland', 'Russia', 'India',
            'China', 'United Arab Emirates', 'Mongolia', 'Online', 'Spain', 'Greece',
             'Greece', 'Serbia', 'Online', 'Greece', 'Online', 'Online', 'Tajikistan',
             'Montenegro', 'Uganda', 'Russia', 'Online', 'Zambia', 'Iceland', 'Online', 
             'Online', 'Online', 'Georgia']

loc_dict = {}
for i in range(len(locs)):
    loc_dict[locs[i]] = countries[i]

# %%
games['country'] = games.apply(lambda r: loc_dict[r['location']], axis = 1)
games = games.drop(columns = ['location'])

# %%
games['medium'] = games.apply(lambda r: 'online' if r['country'] == 'Online' else 'offline', axis = 1)

# %% [markdown]
# ### Step 5: map time control to standard, rapid, blitz, bullet

# %%
time_controls = list(games['time_control'].unique())
base_min = [90, 90, 5, 15, 90, 90, 3, 3, 90, 90, 20, 25, 90, 3, 5, 10, 90, 90, 90, 90, 90, 90,
           5, 10, 10, 60, 90, 3, 15, 10, 15, 15, 120, 15, 15, 3, 45, 90, 15, 3, 10, 15, 120, 10, 10,
           15, 120, 90, 90, 90, 100, 3, 10, 90, 90, 15, 10, 10, 15]
increment_sec = [30, 30, 5, 10, 30, 30, 2, 2, 30, 30, 10, 5, 30, 2, 0, 3, 30, 30, 30, 30, 30, 0, 2, 5, 3, 30,
                30, 2, 10, 5, 5, 5, 60, 10, 10, 2, 30, 30, 10, 2, 3, 10, 30, 3, 3, 10, 30, 30, 30, 30, 50,
                2, 5, 30, 30, 10, 3, 3, 5]

total_time = np.array(base_min) + np.array(increment_sec) * 40/60

def time_control(x):
    if x < 3:
        return 'bullet'
    elif x < 15:
        return 'blitz'
    elif x < 60:
        return 'rapid'
    else:
        return 'standard'
    
tc_games = [time_control(x) for x in total_time]

# %%
tc_dict = {}
for i in range(len(time_controls)):
    tc_dict[time_controls[i]] = tc_games[i]

# %%
games['time_control'] = games.apply(lambda r: tc_dict[r['time_control']], axis = 1)

# %%
games
# Out:
#        upset_score  tournament_id  left_fide_id  left_rtg  right_fide_id  \
# 0              0.0       686540.0    13724800.0      1630      4404637.0
# 1              0.0       686540.0    45076995.0      1156     16233751.0
# 2              0.0       686540.0    25683896.0      1537      5602637.0
# 3              0.0       686540.0    16233751.0      1615     13724800.0
# 4             34.0       686540.0      472000.0      1396      9307010.0
# ...            ...            ...           ...       ...            ...
# 27624          0.0       525314.0     4126025.0      2777     24116068.0
# 27625          0.0       525314.0     2020009.0      2842      4126025.0
# 27626          0.0       525314.0    24116068.0      2763      4135539.0
# 27627          0.0       525314.0     8603677.0      2805      4168119.0
# 27628          0.0       525314.0      623539.0      2767      8602883.0
#
#        right_rtg   medium time_control  start_date country
# 0         1306.0  offline     standard  2022/10/21   Malta
# 1         1615.0  offline     standard  2022/10/21   Malta
# 2         1145.0  offline     standard  2022/10/21   Malta
# 3         1630.0  offline     standard  2022/10/21   Malta
# 4         1362.0  offline     standard  2022/10/21   Malta
# ...          ...      ...          ...         ...     ...
# 27624     2763.0  offline     standard  2020/03/17  Russia
# 27625     2777.0  offline     standard  2020/03/17  Russia
# 27626     2698.0  offline     standard  2020/03/17  Russia
# 27627     2774.0  offline     standard  2020/03/17  Russia
# 27628     2762.0  offline     standard  2020/03/17  Russia
#
# [27629 rows x 10 columns]

# %% [markdown]
# ### Step 7: get games in which there is a difference in rating of >= 200 (can change this threshold later)

# %%
cond = np.abs(games['left_rtg'] - games['right_rtg']) >= 200
games_200 = games[cond]

# %%
games_200
# Out:
#        upset_score  tournament_id  left_fide_id  left_rtg  right_fide_id  \
# 0              0.0       686540.0    13724800.0      1630      4404637.0
# 1              0.0       686540.0    45076995.0      1156     16233751.0
# 2              0.0       686540.0    25683896.0      1537      5602637.0
# 5              0.0       686540.0     5602637.0      1145      9309535.0
# 6            270.0       686540.0     9309535.0      1345     16233751.0
# ...            ...            ...           ...       ...            ...
# 27546        176.0       539708.0     5143128.0      1534      5160464.0
# 27550        107.5       530107.0    13603280.0      1797     13612077.0
# 27558        101.0       530107.0    13603280.0      1797     13612476.0
# 27562          0.0       530107.0    13615939.0      2012     13603280.0
# 27566        274.0       530107.0    13603280.0      1797     13614576.0
#
#        right_rtg   medium time_control  start_date  country
# 0         1306.0  offline     standard  2022/10/21    Malta
# 1         1615.0  offline     standard  2022/10/21    Malta
# 2         1145.0  offline     standard  2022/10/21    Malta
# 5         1345.0  offline     standard  2022/10/21    Malta
# 6         1615.0  offline     standard  2022/10/21    Malta
# ...          ...      ...          ...         ...      ...
# 27546     1182.0   online        blitz  2020/11/01   Online
# 27550     2012.0  offline        rapid  2020/07/09  Georgia
# 27558     1999.0  offline        rapid  2020/07/09  Georgia
# 27562     1797.0  offline        rapid  2020/07/09  Georgia
# 27566     2071.0  offline        rapid  2020/07/09  Georgia
#
# [16353 rows x 10 columns]

# %% [markdown]
# ### Step 6: get each player's basic information (invalid means not found, or missing information)
# ### e.g. 10207570 missing birth year

# %%
def get_player_basic_info(fide_id):
  ## input = string FIDE ID
  try:
    url = "https://ratings.fide.com/profile/" + fide_id
    page = requests.get(url)
    soup = BeautifulSoup(page.text)
    name = soup.find("div", {"class":"col-lg-8 profile-top-title"}).text.strip()
    other_data = soup.find_all("div", {"class":"profile-top-info__block__row__data"})
    fed = other_data[1].text.strip()
    yob = int(other_data[3].text.strip())
    sex = other_data[4].text.strip()
    return (name, fed, yob, sex)
  except:
    print("FIDE ID " + fide_id +  " invalid")

# %%
get_player_basic_info('13724800')
# Out:
# ('Alipbek, Arailym', 'Kazakhstan', 2005, 'Female')

# %%
all_players = list(set(games_200['left_fide_id']).union(set(games_200['right_fide_id'])))

# %%
len(all_players)
# Out:
# 4482

# %%
players_info = {}

for player in tqdm(all_players):
    players_info[player] = get_player_basic_info(str(int(player)))
# Out:
#   2%|▏         | 88/4482 [01:03<51:57,  1.41it/s]
# FIDE ID 10207570 invalid
#  16%|█▌        | 716/4482 [09:44<1:10:32,  1.12s/it]
# FIDE ID 6703690 invalid
#  23%|██▎       | 1025/4482 [13:51<43:47,  1.32it/s]
# FIDE ID 6000207 invalid
#  23%|██▎       | 1033/4482 [13:57<36:38,  1.57it/s]
# FIDE ID 28380791 invalid
#  27%|██▋       | 1197/4482 [15:59<37:40,  1.45it/s]
# FIDE ID 10211446 invalid
#  37%|███▋      | 1676/4482 [21:50<38:00,  1.23it/s]
# FIDE ID 9000810 invalid
#  39%|███▊      | 1732/4482 [22:33<45:02,  1.02it/s]
# FIDE ID 5216257 invalid
#  40%|███▉      | 1779/4482 [23:07<33:40,  1.34it/s]
# FIDE ID 8607966 invalid
#  42%|████▏     | 1862/4482 [24:10<34:00,  1.28it/s]
# FIDE ID 9001476 invalid
#  42%|████▏     | 1864/4482 [24:13<52:05,  1.19s/it]
# FIDE ID 3824144 invalid
#  42%|████▏     | 1877/4482 [24:27<46:21,  1.07s/it]
# FIDE ID 3824179 invalid
#  45%|████▌     | 2018/4482 [27:08<1:00:07,  1.46s/it]
# FIDE ID 5200938 invalid
#  50%|████▉     | 2236/4482 [31:16<38:32,  1.03s/it]
# FIDE ID 8609772 invalid
#  50%|█████     | 2260/4482 [31:42<37:25,  1.01s/it]
# FIDE ID 3301435 invalid
#  63%|██████▎   | 2814/4482 [42:30<32:26,  1.17s/it]
# FIDE ID 5204100 invalid
#  63%|██████▎   | 2817/4482 [42:33<29:12,  1.05s/it]
# FIDE ID 10201246 invalid
#  63%|██████▎   | 2833/4482 [42:56<36:01,  1.31s/it]
# FIDE ID 7301340 invalid
#  75%|███████▌  | 3378/4482 [53:18<16:07,  1.14it/s]
# FIDE ID 3813630 invalid
#  79%|███████▉  | 3552/4482 [56:03<14:32,  1.07it/s]
# FIDE ID 5206944 invalid
#  82%|████████▏ | 3661/4482 [57:48<11:22,  1.20it/s]
# FIDE ID 5600480 invalid
#  82%|████████▏ | 3687/4482 [58:10<11:11,  1.18it/s]
# FIDE ID 5600570 invalid
#  83%|████████▎ | 3716/4482 [58:40<15:32,  1.22s/it]
# FIDE ID 10204563 invalid
#  83%|████████▎ | 3726/4482 [58:51<16:23,  1.30s/it]
# FIDE ID 5600715 invalid
#  86%|████████▌ | 3855/4482 [1:00:49<07:52,  1.33it/s]
# FIDE ID 5601118 invalid
#  88%|████████▊ | 3945/4482 [1:02:07<07:37,  1.17it/s]
# FIDE ID 10205373 invalid
#  91%|█████████ | 4071/4482 [1:03:50<04:42,  1.45it/s]
# FIDE ID 5716659 invalid
#  92%|█████████▏| 4126/4482 [1:04:34<04:20,  1.37it/s]
# FIDE ID 5208939 invalid
#  94%|█████████▎| 4195/4482 [1:05:26<03:43,  1.29it/s]
# FIDE ID 3406911 invalid
# 100%|██████████| 4482/4482 [1:09:01<00:00,  1.08it/s]

# %%
len(players_info)
# Out:
# 4482

# %%
games_200['left_info'] = games_200.apply(lambda r: players_info[r['left_fide_id']], axis = 1)
games_200['right_info'] = games_200.apply(lambda r: players_info[r['right_fide_id']], axis = 1)
# Out:
# <ipython-input-84-819cf082a9c8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games_200['left_info'] = games_200.apply(lambda r: players_info[r['left_fide_id']], axis = 1)
# <ipython-input-84-819cf082a9c8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games_200['right_info'] = games_200.apply(lambda r: players_info[r['right_fide_id']], axis = 1)

# %%
games_200 = games_200.dropna()

# %%
games_200.head()
# Out:
#    upset_score  tournament_id  left_fide_id  left_rtg  right_fide_id  \
# 0          0.0       686540.0    13724800.0      1630      4404637.0
# 1          0.0       686540.0    45076995.0      1156     16233751.0
# 2          0.0       686540.0    25683896.0      1537      5602637.0
# 5          0.0       686540.0     5602637.0      1145      9309535.0
# 6        270.0       686540.0     9309535.0      1345     16233751.0
#
#    right_rtg   medium time_control  start_date country  \
# 0     1306.0  offline     standard  2022/10/21   Malta
# 1     1615.0  offline     standard  2022/10/21   Malta
# 2     1145.0  offline     standard  2022/10/21   Malta
# 5     1345.0  offline     standard  2022/10/21   Malta
# 6     1615.0  offline     standard  2022/10/21   Malta
#
#                                            left_info  \
# 0       (Alipbek, Arailym, Kazakhstan, 2005, Female)
# 1                   (Rani Puja, India, 1995, Female)
# 2           (Amulya Guruprasad, India, 2008, Female)
# 5            (Thornton, Hayley, Malta, 2011, Female)
# 6  (Aysha Nasser H Alshamsi, United Arab Emirates...
#
#                                           right_info
# 0        (Jaramillo, Amparo, Colombia, 1957, Female)
# 1         (von Beckh, Frieda, Germany, 2007, Female)
# 2            (Thornton, Hayley, Malta, 2011, Female)
# 5  (Aysha Nasser H Alshamsi, United Arab Emirates...
# 6         (von Beckh, Frieda, Germany, 2007, Female)

# %% [markdown]
# ### Step 7: reorder so that left player is of higher rating, for consistency; clean up table, add covariate columns

# %%
games_200_reordered = pd.DataFrame(columns = games_200.columns)

for i in range(games_200.shape[0]):
    data = games_200.iloc[i]
    
    if data['left_rtg'] > data['right_rtg']:
        games_200_reordered.loc[len(games_200_reordered)] = list(data)
        
    else:
        cols_order = ['upset_score', 'tournament_id', 'right_fide_id', 'right_rtg',
                      'left_fide_id', 'left_rtg', 'medium', 'time_control', 'start_date',
                      'country', 'right_info', 'left_info']
        games_200_reordered.loc[len(games_200_reordered)] = list(data[cols_order])

# %%
games_200_reordered['left_country'] = games_200_reordered.apply(lambda r: r['left_info'][1], axis = 1)
games_200_reordered['left_birth'] = games_200_reordered.apply(lambda r: r['left_info'][2], axis = 1)
games_200_reordered['left_sex'] = games_200_reordered.apply(lambda r: r['left_info'][3], axis = 1)
games_200_reordered['right_country'] = games_200_reordered.apply(lambda r: r['right_info'][1], axis = 1)
games_200_reordered['right_birth'] = games_200_reordered.apply(lambda r: r['right_info'][2], axis = 1)
games_200_reordered['right_sex'] = games_200_reordered.apply(lambda r: r['right_info'][3], axis = 1)

# %%
games_200_reordered = games_200_reordered.drop(columns = ['left_info', 'right_info'])

# %%
cols_order = ['tournament_id', 'start_date', 'medium', 'country', 'time_control', 
             'left_fide_id', 'left_rtg', 'left_country', 'left_birth', 'left_sex',
             'right_fide_id', 'right_rtg', 'right_country', 'right_birth', 'right_sex',
             'upset_score']

games_200_reordered = games_200_reordered[cols_order]

# %%
games_200_reordered['left_age'] = games_200_reordered.apply(lambda r: int(r['start_date'].split('/')[0]) - 
                                                            r['left_birth'], axis = 1)
games_200_reordered['right_age'] = games_200_reordered.apply(lambda r: int(r['start_date'].split('/')[0]) - 
                                                            r['right_birth'], axis = 1)
# Out:
# <ipython-input-103-1a97c480d0ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games_200_reordered['left_age'] = games_200_reordered.apply(lambda r: int(r['start_date'].split('/')[0]) -
# <ipython-input-103-1a97c480d0ce>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games_200_reordered['right_age'] = games_200_reordered.apply(lambda r: int(r['start_date'].split('/')[0]) -

# %%
games_200_reordered = games_200_reordered.drop(columns = ['left_birth', 'right_birth'])

# %%
cols_order = ['tournament_id', 'start_date', 'medium', 'country', 'time_control', 
             'left_fide_id', 'left_rtg', 'left_country', 'left_age', 'left_sex',
             'right_fide_id', 'right_rtg', 'right_country', 'right_age', 'right_sex',
             'upset_score']

games_200_reordered = games_200_reordered[cols_order]

# %%
games_200_reordered['upset'] = games_200_reordered.apply(lambda r: int(r['upset_score'] > 0), axis = 1)

# %%
games_200_reordered['upset'].value_counts()
# Out:
# 0    10615
# 1     5577
# Name: upset, dtype: int64

# %%
def left_home_country(r):
    if r['medium'] == 'online':
        return 1
    else:
        if r['country'] == r['left_country']:
            return 1
        else:
            return 0
        
def right_home_country(r):
    if r['medium'] == 'online':
        return 1
    else:
        if r['country'] == r['right_country']:
            return 1
        else:
            return 0

# %%
games_200_reordered['left_home_country'] = games_200_reordered.apply(left_home_country, axis = 1)
games_200_reordered['right_home_country'] = games_200_reordered.apply(right_home_country, axis = 1)
games_200_reordered['home_country_diff'] = games_200_reordered['left_home_country'] \
    - games_200_reordered['right_home_country']

# %%
games_200_reordered['age_diff'] = games_200_reordered['left_age'] - games_200_reordered['right_age']

# %%
def sex_cat(r):
    if r['left_sex'] == r['right_sex']:
        if r['left_sex'] == 'Male':
            return 'MM'
        else:
            return 'FF'
    else:
        if r['left_sex'] == 'Male':
            return 'MF'
        else:
            return 'FM'

# %%
games_200_reordered['players_sex'] = games_200_reordered.apply(sex_cat, axis = 1)

# %%
games_200_reordered
# Out:
#        tournament_id  start_date   medium  country time_control  left_fide_id  \
# 0           686540.0  2022/10/21  offline    Malta     standard    13724800.0
# 1           686540.0  2022/10/21  offline    Malta     standard    16233751.0
# 2           686540.0  2022/10/21  offline    Malta     standard    25683896.0
# 3           686540.0  2022/10/21  offline    Malta     standard     9309535.0
# 4           686540.0  2022/10/21  offline    Malta     standard    16233751.0
# ...              ...         ...      ...      ...          ...           ...
# 16187       539708.0  2020/11/01   online   Online        blitz     5143128.0
# 16188       530107.0  2020/07/09  offline  Georgia        rapid    13612077.0
# 16189       530107.0  2020/07/09  offline  Georgia        rapid    13612476.0
# 16190       530107.0  2020/07/09  offline  Georgia        rapid    13615939.0
# 16191       530107.0  2020/07/09  offline  Georgia        rapid    13614576.0
#
#        left_rtg          left_country  left_age left_sex  ...  \
# 0        1630.0            Kazakhstan        17   Female  ...
# 1        1615.0               Germany        15   Female  ...
# 2        1537.0                 India        14   Female  ...
# 3        1345.0  United Arab Emirates        18   Female  ...
# 4        1615.0               Germany        15   Female  ...
# ...         ...                   ...       ...      ...  ...
# 16187    1534.0                Mexico        11   Female  ...
# 16188    2012.0               Georgia        20   Female  ...
# 16189    1999.0               Georgia        15   Female  ...
# 16190    2012.0               Georgia        15   Female  ...
# 16191    2071.0               Georgia        17   Female  ...
#
#               right_country  right_age right_sex  upset_score upset  \
# 0                  Colombia         65    Female          0.0     0
# 1                     India         27    Female          0.0     0
# 2                     Malta         11    Female          0.0     0
# 3                     Malta         11    Female          0.0     0
# 4      United Arab Emirates         18    Female        270.0     1
# ...                     ...        ...       ...          ...   ...
# 16187                Mexico         11    Female        176.0     1
# 16188               Georgia         19    Female        107.5     1
# 16189               Georgia         19    Female        101.0     1
# 16190               Georgia         19    Female          0.0     0
# 16191               Georgia         19    Female        274.0     1
#
#        left_home_country  right_home_country  age_diff  home_country_diff  \
# 0                      0                   0       -48                  0
# 1                      0                   0       -12                  0
# 2                      0                   1         3                 -1
# 3                      0                   1         7                 -1
# 4                      0                   0        -3                  0
# ...                  ...                 ...       ...                ...
# 16187                  1                   1         0                  0
# 16188                  1                   1         1                  0
# 16189                  1                   1        -4                  0
# 16190                  1                   1        -4                  0
# 16191                  1                   1        -2                  0
#
#        players_sex
# 0               FF
# 1               FF
# 2               FF
# 3               FF
# 4               FF
# ...            ...
# 16187           FF
# 16188           FF
# 16189           FF
# 16190           FF
# 16191           FF
#
# [16192 rows x 22 columns]

# %%
games_200_reordered.columns
# Out:
# Index(['tournament_id', 'start_date', 'medium', 'country', 'time_control',
#        'left_fide_id', 'left_rtg', 'left_country', 'left_age', 'left_sex',
#        'right_fide_id', 'right_rtg', 'right_country', 'right_age', 'right_sex',
#        'upset_score', 'upset', 'left_home_country', 'right_home_country',
#        'age_diff', 'home_country_diff', 'players_sex'],
#       dtype='object')

# %% [markdown]
# ### Step 8: to ensure the ratings represent 'real' rating of players, only choose games in which both ages are >= 25; add rating diff columns

# %%
games_200_22 = games_200_reordered[(games_200_reordered['left_age'] >= 22) & 
                                   (games_200_reordered['right_age'] >= 22)] \
    .reset_index(drop = True)

# %%
games_200_22['rating_diff'] = games_200_22['left_rtg'] - games_200_22['right_rating']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# /usr/local/anaconda/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/anaconda/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'left_rating'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-168-4087e56b73e0> in <module>
# ----> 1 games_200_22['rating_diff'] = games_200_22['left_rating'] - games_200_22['right_rating']
#
# /usr/local/anaconda/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# /usr/local/anaconda/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'left_rating'

# %%
games_200_22
# Out:
#       tournament_id  start_date   medium country time_control  left_fide_id  \
# 0          686540.0  2022/10/21  offline   Malta     standard     9307010.0
# 1          669871.0  2022/10/21  offline   Malta     standard     2903784.0
# 2          669871.0  2022/10/21  offline   Malta     standard     2007606.0
# 3          669871.0  2022/10/21  offline   Malta     standard     3803392.0
# 4          669871.0  2022/10/21  offline   Malta     standard     1170791.0
# ...             ...         ...      ...     ...          ...           ...
# 2188       552700.0  2021/03/13   online  Online        blitz     3506738.0
# 2189       552700.0  2021/03/13   online  Online        blitz     4259963.0
# 2190       552700.0  2021/03/13   online  Online        blitz    14135132.0
# 2191       552700.0  2021/03/13   online  Online        blitz     3517489.0
# 2192       542325.0  2020/12/04  offline   China        rapid     8602980.0
#
#       left_rtg              left_country  left_age left_sex  ...  \
# 0       1362.0      United Arab Emirates        23   Female  ...
# 1       2255.0                  Bulgaria        46     Male  ...
# 2       2246.0  United States of America        58     Male  ...
# 3       2243.0                     Spain        29     Male  ...
# 4       2226.0                    Poland        27     Male  ...
# ...        ...                       ...       ...      ...  ...
# 2188    2024.0                      Cuba        22     Male  ...
# 2189    2236.0                    Greece        22     Male  ...
# 2190    1926.0                   Ukraine        23     Male  ...
# 2191    2025.0                      Cuba        24   Female  ...
# 2192    2658.0                     China        26   Female  ...
#
#       right_country  right_age right_sex  upset_score upset  \
# 0             India         27    Female        103.0     1
# 1            Poland         25      Male        220.0     1
# 2        Uzbekistan         36      Male        213.0     1
# 3            Israel         66      Male          0.0     0
# 4             India         41      Male        204.0     1
# ...             ...        ...       ...          ...   ...
# 2188         Mexico         22    Female          0.0     0
# 2189         Greece         22      Male          0.0     0
# 2190          India         22      Male          0.0     0
# 2191         Uganda         22    Female          0.0     0
# 2192        Turkiye         38    Female          0.0     0
#
#       left_home_country  right_home_country  age_diff  home_country_diff  \
# 0                     0                   0        -4                  0
# 1                     0                   0        21                  0
# 2                     0                   0        22                  0
# 3                     0                   0       -37                  0
# 4                     0                   0       -14                  0
# ...                 ...                 ...       ...                ...
# 2188                  1                   1         0                  0
# 2189                  1                   1         0                  0
# 2190                  1                   1         1                  0
# 2191                  1                   1         2                  0
# 2192                  1                   0       -12                  1
#
#       players_sex
# 0              FF
# 1              MM
# 2              MM
# 3              MM
# 4              MM
# ...           ...
# 2188           MF
# 2189           MM
# 2190           MM
# 2191           FF
# 2192           FF
#
# [2193 rows x 22 columns]

# %%
games_200_22['medium'].value_counts()
# Out:
# offline    1185
# online     1008
# Name: medium, dtype: int64

# %%
games_200_22['upset'].value_counts()
# Out:
# 0    1537
# 1     656
# Name: upset, dtype: int64

# %%
games_200_22['home_country_diff'].value_counts()
# Out:
#  0    1899
# -1     230
#  1      64
# Name: home_country_diff, dtype: int64

# %%
games_200_22['players_sex'].value_counts()
# Out:
# MM    1526
# FF     306
# MF     267
# FM      94
# Name: players_sex, dtype: int64

# %%
games_200_22['time_control'].value_counts()
# Out:
# blitz       1252
# standard     650
# rapid        291
# Name: time_control, dtype: int64

# %%
games_200_22.to_csv('games_200_22.csv')

# %%
cov_cols = ['medium', 'time_control', 'age_diff', 'home_country_diff', 'players_sex', 'upset']
games_200_22_clean = games_200_22[cov_cols]

# %%
games_200_22_clean
# Out:
#        medium time_control  age_diff  home_country_diff players_sex  upset
# 0     offline     standard        -4                  0          FF      1
# 1     offline     standard        21                  0          MM      1
# 2     offline     standard        22                  0          MM      1
# 3     offline     standard       -37                  0          MM      0
# 4     offline     standard       -14                  0          MM      1
# ...       ...          ...       ...                ...         ...    ...
# 2188   online        blitz         0                  0          MF      0
# 2189   online        blitz         0                  0          MM      0
# 2190   online        blitz         1                  0          MM      0
# 2191   online        blitz         2                  0          FF      0
# 2192  offline        rapid       -12                  1          FF      0
#
# [2193 rows x 6 columns]
